# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
books=pd.read_csv('books.csv')
users=pd.read_csv('users.csv')
ratings=pd.read_csv('ratings.csv')
# Out:
# C:\Users\shudh\AppData\Local\Temp\ipykernel_26016\1004906641.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('books.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books.describe
# Out:
# <bound method NDFrame.describe of               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# ...

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books.columns.values
# Out:
# array(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication',
#        'Publisher', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype=object)

# %%
users.columns.values
# Out:
# array(['User-ID', 'Location', 'Age'], dtype=object)

# %%
ratings.columns.values
# Out:
# array(['User-ID', 'ISBN', 'Book-Rating'], dtype=object)

# %% [markdown]
# # EDA

# %%
books['Year-Of-Publication'].value_counts()
# Out:
# Year-Of-Publication
# 2002    13903
# 2001    13715
# 1999    13414
# 2000    13373
# 1998    12116
#         ...
# 1924        1
# 2012        1
# 1927        1
# 1931        1
# 2037        1
# Name: count, Length: 202, dtype: int64

# %%
# valid_years = books['Year-Of-Publication'].astype(str).str.isnumeric()
# # books['Year-Of-Publication'].dtype
# books_valid=books[valid_years]
ratings['Book-Rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Book-Rating'>

# %% [markdown]
# # Recommender system

# %%
#top 50 highest avg rating min of 200 votes

# %%
rated_books=ratings.merge(books,on='ISBN')

# %%
rated_books
total_books=users.merge(rated_books,on='User-ID')
total_books
# Out:
#          User-ID                   Location   Age        ISBN  Book-Rating  \
# 0              2  stockton, california, usa  18.0  0195153448            0
# 1              8   timmins, ontario, canada   NaN  0002005018            5
# 2              8   timmins, ontario, canada   NaN  0060973129            0
# 3              8   timmins, ontario, canada   NaN  0374157065            0
# 4              8   timmins, ontario, canada   NaN  0393045218            0
# ...          ...                        ...   ...         ...          ...
# 1031131   278854      portland, oregon, usa   NaN  0375703063            7
# 1031132   278854      portland, oregon, usa   NaN  0316184152            7
# 1031133   278854      portland, oregon, usa   NaN  0425163393            7
# 1031134   278854      portland, oregon, usa   NaN  0553275739            6
# 1031135   278854      portland, oregon, usa   NaN  0553578596            0
#
#                                                 Book-Title  \
# ...

# %%
# rated_books.groupby('User-ID').count()
rated_books.groupby('Book-Title').count()
rated_books.groupby('Book-Title').count()['Book-Rating']
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    4
#  Always Have Popsicles                                                                                        1
#  Apple Magic (The Collector's series)                                                                         1
#  Ask Lily (Young Women of Faith: Lily Series, Book 5)                                                         1
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   1
#                                                                                                              ..
# Ã?Â?lpiraten.                                                                                                 2
# Ã?Â?rger mit Produkt X. Roman.                                                                                4
# ...

# %%
# rated_books['Book-Rating'] = pd.to_numeric(rated_books['Book-Rating'], errors='coerce') 
total_rating=rated_books.groupby('Book-Title').count()['Book-Rating'].reset_index()
total_rating.rename(columns={'Book-Rating':'total_rating'},inplace=True)
total_rating
# Out:
#                                                Book-Title  total_rating
# 0        A Light in the Storm: The Civil War Diary of ...             4
# 1                                   Always Have Popsicles             1
# 2                    Apple Magic (The Collector's series)             1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...             1
# 4        Beyond IBM: Leadership Marketing and Finance ...             1
# ...                                                   ...           ...
# 241066                                      Ã?Â?lpiraten.             2
# 241067                     Ã?Â?rger mit Produkt X. Roman.             4
# 241068                                Ã?Â?sterlich leben.             1
# 241069                              Ã?Â?stlich der Berge.             3
# 241070                                  Ã?Â?thique en toc             2
#
# [241071 rows x 2 columns]

# %%
# avg_rating=rated_books.groupby('Book-Title').mean()['Book-Rating'].reset_index()
# avg_rating.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
# avg_rating
avg_rating = rated_books.groupby('Book-Title')['Book-Rating'].apply(lambda x: pd.to_numeric(x, errors='coerce').mean()).reset_index()

# Rename the column
avg_rating.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)

# Filter out rows where the mean couldn't be calculated (due to all non-numeric values)
avg_rating = avg_rating[~avg_rating['avg_rating'].isna()]
avg_rating
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular=total_rating.merge(avg_rating,on='Book-Title')
popular
# Out:
#                                                Book-Title  total_rating  \
# 0        A Light in the Storm: The Civil War Diary of ...             4
# 1                                   Always Have Popsicles             1
# 2                    Apple Magic (The Collector's series)             1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...             1
# 4        Beyond IBM: Leadership Marketing and Finance ...             1
# ...                                                   ...           ...
# 241066                                      Ã?Â?lpiraten.             2
# 241067                     Ã?Â?rger mit Produkt X. Roman.             4
# 241068                                Ã?Â?sterlich leben.             1
# 241069                              Ã?Â?stlich der Berge.             3
# 241070                                  Ã?Â?thique en toc             2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
top_50=popular[popular['total_rating']>=200].sort_values('avg_rating',ascending=False).head(50)
top_50
# Out:
#                                                Book-Title  total_rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)           428
# 80422        Harry Potter and the Goblet of Fire (Book 4)           387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)           278
# 80426   Harry Potter and the Order of the Phoenix (Boo...           347
# 60582       Ender's Game (Ender Wiggins Saga (Paperback))           249
# 80414    Harry Potter and the Chamber of Secrets (Book 2)           556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...           281
# 187377  The Fellowship of the Ring (The Lord of the Ri...           368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...           575
# 211384     The Two Towers (The Lord of the Rings, Part 2)           260
# 219741                              To Kill a Mockingbird           510
# 183573                                  The Da Vinci Code           898
# ...

# %%
top_50= top_50.merge(books,on='Book-Title').drop_duplicates('Book-Title')
top_50
# Out:
#                                             Book-Title  total_rating  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)           428
# 3         Harry Potter and the Goblet of Fire (Book 4)           387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)           278
# 9    Harry Potter and the Order of the Phoenix (Boo...           347
# 13       Ender's Game (Ender Wiggins Saga (Paperback))           249
# 17    Harry Potter and the Chamber of Secrets (Book 2)           556
# 20   The Hobbit : The Enchanting Prelude to The Lor...           281
# 21   The Fellowship of the Ring (The Lord of the Ri...           368
# 30   Harry Potter and the Sorcerer's Stone (Harry P...           575
# 32      The Two Towers (The Lord of the Rings, Part 2)           260
# 43                               To Kill a Mockingbird           510
# 51                                   The Da Vinci Code           898
# 57                  The Five People You Meet in Heaven           430
# ...

# %%
top_50=top_50[['total_rating','avg_rating','Book-Title','Book-Author','Image-URL-M']]
top_50
# Out:
#      total_rating  avg_rating  \
# 0             428    5.852804
# 3             387    5.824289
# 5             278    5.737410
# 9             347    5.501441
# 13            249    5.409639
# 17            556    5.183453
# 20            281    5.007117
# 21            368    4.948370
# 30            575    4.895652
# 32            260    4.880769
# 43            510    4.700000
# 51            898    4.642539
# 57            430    4.551163
# 59            449    4.545657
# 66            211    4.497630
# 76           1295    4.468726
# 77            205    4.458537
# 79            284    4.454225
# 88            253    4.450593
# 89            265    4.449057
# 94            774    4.447028
# 100           283    4.356890
# 101           493    4.354970
# 104           723    4.334716
# 105           226    4.331858
# 110           268    4.328358
# 119           335    4.289552
# 121           211    4.289100
# 123           233    4.274678
# 133           252    4.273810
# ...

# %% [markdown]
# # Collaborative-Filter model

# %%
#considering users having reviews more than 200 as we want to find the genuine reiviewers 
ok=rated_books.groupby('User-ID').count()['Book-Rating']>200
ok[ok]
#ok[ok]->selects only  true rows
# trusted_reviewers=ok[ok].index
# Out:
# User-ID
# 254       True
# 2276      True
# 2766      True
# 2977      True
# 3363      True
#           ...
# 274308    True
# 275970    True
# 277427    True
# 277639    True
# 278418    True
# Name: Book-Rating, Length: 811, dtype: bool

# %%
g_reviewers=ok[ok].index

# %%
tru=rated_books['User-ID'].isin(g_reviewers)
filtered_ratings=rated_books[tru] #contains books which have been reviwed by g_reviewers only

# %%
y=filtered_ratings.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index

# %%
final_ratings=filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]

# %%
final_ratings.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
tab=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
tab.fillna(0,inplace=True)
tab
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
#706 books and 810 reviewres
#from above table we can say that every book has a vectror of total 810 rep each

# %% [markdown]
# Relation of books

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(tab)
similarity_score
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
# def recommend(book_name):
#     index=np.where(tab.index==book_name)[0][0]
#     distances=similarity_score[index]#similarity score of current book with every other book
#     similar_items=sorted(list(enumerate(similarity_score[index])),key= lambda x:x[1],reverse=True)[1:10]
    
#     for i in similar_items:
#         print(tab.index[i[0]])
#     return suggestions
def recommend(book_name):
   
    index = np.where(tab.index==book_name)[0][0]

    similar_items = sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1],reverse=True)[1:5]
    #sorting on the basis of similarity score enumaretes gives (index,simscore) i.e x[1]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == tab.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('A Bend in the Road')
# index = np.where(tab.index=='1984')[0][0]
# Out:
# [['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ['The Last Time They Met : A Novel',
#   'Anita Shreve',
#   'http://images.amazon.com/images/P/0316781266.01.MZZZZZZZ.jpg'],
#  ['Sea Glass: A Novel',
#   'Anita Shreve',
#   'http://images.amazon.com/images/P/0316089699.01.MZZZZZZZ.jpg'],
#  ['Angels',
#   'Marian Keyes',
#   'http://images.amazon.com/images/P/0060008024.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(tab,open('tab.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_score,open('similarity_score.pkl','wb'))
